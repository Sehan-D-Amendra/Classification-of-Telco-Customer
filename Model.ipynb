# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename = 'TelcoCustomerChurn.csv'

Customer_Churn_data = pd.read_csv(filename, encoding='latin-1')

# %%
Customer_Churn_data.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Customer_Churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# # Check Null Values

# %%
Customer_Churn_data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.heatmap(Customer_Churn_data.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
sns.countplot(x='Churn', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='gender', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='SeniorCitizen', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='Partner', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='Dependents', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='tenure', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='PhoneService', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='MultipleLines', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='InternetService', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='OnlineSecurity', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='OnlineBackup', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='StreamingMovies', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='Contract', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='PaperlessBilling', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='PaymentMethod', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
sns.countplot(x='Churn', hue='MonthlyCharges', data=Customer_Churn_data)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
Customer_Churn_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
Customer_Churn_data['gender'].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
Customer_Churn_data['Partner'].value_counts()
# Out:
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
Customer_Churn_data['Dependents'].value_counts()
# Out:
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64

# %%
Customer_Churn_data['PhoneService'].value_counts()
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64

# %%
Customer_Churn_data['MultipleLines'].value_counts()
# Out:
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
Customer_Churn_data['InternetService'].value_counts()
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['OnlineSecurity'].value_counts()
# Out:
# OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['OnlineBackup'].value_counts()
# Out:
# OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['DeviceProtection'].value_counts()
# Out:
# DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['TechSupport'].value_counts()
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['StreamingTV'].value_counts()
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['StreamingMovies'].value_counts()
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
Customer_Churn_data['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
Customer_Churn_data['PaperlessBilling'].value_counts()
# Out:
# PaperlessBilling
# Yes    4171
# No     2872
# Name: count, dtype: int64

# %%
Customer_Churn_data['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
Customer_Churn_data['MonthlyCharges'].value_counts()
# Out:
# MonthlyCharges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 20.00     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: count, Length: 1585, dtype: int64

# %%
yes_no_mapping = {'Yes': 1, 'No': 0}

Customer_Churn_data['Partner'] = Customer_Churn_data['Partner'].map(yes_no_mapping)
Customer_Churn_data['Dependents'] = Customer_Churn_data['Dependents'].map(yes_no_mapping)
Customer_Churn_data['PhoneService'] = Customer_Churn_data['PhoneService'].map(yes_no_mapping)

# %%
InternetServiceMapping = {'Yes' : 1, 'No' : 0 , 'No internet service' : 0}

Customer_Churn_data['OnlineSecurity'] = Customer_Churn_data['OnlineSecurity'].map(InternetServiceMapping)
Customer_Churn_data['OnlineBackup'] = Customer_Churn_data['OnlineBackup'].map(InternetServiceMapping)
Customer_Churn_data['DeviceProtection'] = Customer_Churn_data['DeviceProtection'].map(InternetServiceMapping)
Customer_Churn_data['TechSupport'] = Customer_Churn_data['TechSupport'].map(InternetServiceMapping)
Customer_Churn_data['StreamingTV'] = Customer_Churn_data['StreamingTV'].map(InternetServiceMapping)
Customer_Churn_data['StreamingMovies'] = Customer_Churn_data['StreamingMovies'].map(InternetServiceMapping)

# %%
PhoneServiceMapping = {'Yes' : 1, 'No' : 0 , 'No phone service' : 0}

Customer_Churn_data['MultipleLines'] = Customer_Churn_data['MultipleLines'].map(PhoneServiceMapping)

# %%
Customer_Churn_data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# ...

# %%
ContractMapping = {'Month-to-month' : 'MM', 'One year' : 'OY', 'Two year' : 'TY'}

Customer_Churn_data['Contract'] = Customer_Churn_data['Contract'].map(ContractMapping)

# %%
Customer_Churn_data['PaperlessBilling'] = Customer_Churn_data['PaperlessBilling'].map(yes_no_mapping)

# %%
Customer_Churn_data['PaymentMethod'].value_counts()
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
PaymentMapping = {'Bank transfer (automatic)' : 'Bank', 'Credit card (automatic)' : 'Card', 'Electronic check' : 'Check', 'Mailed check' : 'Check'}

Customer_Churn_data['PaymentMethod'] = Customer_Churn_data['PaymentMethod'].map(PaymentMapping)

# %%
Customer_Churn_data['Churn'] = Customer_Churn_data['Churn'].map(yes_no_mapping)

# %%
Customer_Churn_data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG  Female              0        1           0       1
# 1     5575-GNVDE    Male              0        0           0      34
# 2     3668-QPYBK    Male              0        0           0       2
# 3     7795-CFOCW    Male              0        0           0      45
# 4     9237-HQITU  Female              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB    Male              0        1           1      24
# 7039  2234-XADUH  Female              0        1           1      72
# 7040  4801-JZAZL  Female              0        1           1      11
# 7041  8361-LTMKD    Male              1        1           0       4
# 7042  3186-AJIEK    Male              0        0           0      66
#
#       PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# ...

# %%
sex = pd.get_dummies(Customer_Churn_data['gender'], drop_first=True)
sex
# Out:
#        Male
# 0     False
# 1      True
# 2      True
# 3      True
# 4     False
# ...     ...
# 7038   True
# 7039  False
# 7040  False
# 7041   True
# 7042   True
#
# [7043 rows x 1 columns]

# %%
sex['Male'] = sex['Male'].map({True:1,False:0})

# %%
sex
# Out:
#       Male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
# ...    ...
# 7038     1
# 7039     0
# 7040     0
# 7041     1
# 7042     1
#
# [7043 rows x 1 columns]

# %%
contract = pd.get_dummies(Customer_Churn_data['Contract'], drop_first=True)

# %%
contract
# Out:
#          OY     TY
# 0     False  False
# 1      True  False
# 2     False  False
# 3      True  False
# 4     False  False
# ...     ...    ...
# 7038   True  False
# 7039   True  False
# 7040  False  False
# 7041  False  False
# 7042  False   True
#
# [7043 rows x 2 columns]

# %%
contract['OY'] = contract['OY'].map({True:1,False:0})
contract['TY'] = contract['TY'].map({True:1,False:0})

# %%
contract
# Out:
#       OY  TY
# 0      0   0
# 1      1   0
# 2      0   0
# 3      1   0
# 4      0   0
# ...   ..  ..
# 7038   1   0
# 7039   1   0
# 7040   0   0
# 7041   0   0
# 7042   0   1
#
# [7043 rows x 2 columns]

# %%
paymethod = pd.get_dummies(Customer_Churn_data['PaymentMethod'], drop_first=True)

# %%
paymethod
# Out:
#        Card  Check
# 0     False   True
# 1     False   True
# 2     False   True
# 3     False  False
# 4     False   True
# ...     ...    ...
# 7038  False   True
# 7039   True  False
# 7040  False   True
# 7041  False   True
# 7042  False  False
#
# [7043 rows x 2 columns]

# %%
paymethod['Card'] = paymethod['Card'].map({True:1,False:0})
paymethod['Check'] = paymethod['Check'].map({True:1,False:0})

# %%
paymethod
# Out:
#       Card  Check
# 0        0      1
# 1        0      1
# 2        0      1
# 3        0      0
# 4        0      1
# ...    ...    ...
# 7038     0      1
# 7039     1      0
# 7040     0      1
# 7041     0      1
# 7042     0      0
#
# [7043 rows x 2 columns]

# %%
Customer_Churn_data = pd.concat([Customer_Churn_data,sex,contract,paymethod], axis=1)

# %%
Customer_Churn_data.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0             0              0             DSL               0  ...
# 1             1              0             DSL               1  ...
# 2             1              0             DSL               1  ...
# 3             0              0             DSL               1  ...
# 4             1              0     Fiber optic               0  ...
#
#    PaperlessBilling  PaymentMethod  MonthlyCharges  TotalCharges  Churn Male  \
# 0                 1          Check           29.85         29.85      0    0
# ...

# %%
Customer_Churn_data.drop(['customerID', 'gender', 'PaymentMethod', 'Contract'], axis = 1, inplace=True)

# %%
Customer_Churn_data
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0                 0        1           0       1             0              0
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 3                 0        0           0      45             0              0
# 4                 0        0           0       2             1              0
# ...             ...      ...         ...     ...           ...            ...
# 7038              0        1           1      24             1              1
# 7039              0        1           1      72             1              1
# 7040              0        1           1      11             0              0
# 7041              1        1           0       4             1              1
# 7042              0        0           0      66             1              0
#
# ...

# %%
DSLFiberMapping = {'DSL' : 1, 'Fiber optic' : 1, 'No' : 0}

Customer_Churn_data['InternetService'] = Customer_Churn_data['InternetService'].map(DSLFiberMapping)

# %%
Customer_Churn_data
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0                 0        1           0       1             0              0
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 3                 0        0           0      45             0              0
# 4                 0        0           0       2             1              0
# ...             ...      ...         ...     ...           ...            ...
# 7038              0        1           1      24             1              1
# 7039              0        1           1      72             1              1
# 7040              0        1           1      11             0              0
# 7041              1        1           0       4             1              1
# 7042              0        0           0      66             1              0
#
# ...

# %% [markdown]
# # Encording

# %%
from sklearn.preprocessing import LabelEncoder
lblEnc = LabelEncoder()
churn_data_tf = Customer_Churn_data.copy()

for i in Customer_Churn_data.columns:
    churn_data_tf[i] = lblEnc.fit_transform(Customer_Churn_data[i])

# %%
churn_data_tf
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0                 0        1           0       1             0              0
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 3                 0        0           0      45             0              0
# 4                 0        0           0       2             1              0
# ...             ...      ...         ...     ...           ...            ...
# 7038              0        1           1      24             1              1
# 7039              0        1           1      72             1              1
# 7040              0        1           1      11             0              0
# 7041              1        1           0       4             1              1
# 7042              0        0           0      66             1              0
#
# ...

# %%
Customer_Churn_data
# Out:
#       SeniorCitizen  Partner  Dependents  tenure  PhoneService  MultipleLines  \
# 0                 0        1           0       1             0              0
# 1                 0        0           0      34             1              0
# 2                 0        0           0       2             1              0
# 3                 0        0           0      45             0              0
# 4                 0        0           0       2             1              0
# ...             ...      ...         ...     ...           ...            ...
# 7038              0        1           1      24             1              1
# 7039              0        1           1      72             1              1
# 7040              0        1           1      11             0              0
# 7041              1        1           0       4             1              1
# 7042              0        0           0      66             1              0
#
# ...

# %%
X = churn_data_tf.drop('Churn', axis = 1)
Y = churn_data_tf['Churn']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 2)

# %%
print(X_train.shape, '-----> Training Feature Shape')
print(X_test.shape, '-----> Testing Feature Shape')
print(Y_train.shape, '-----> Training Labels Shape')
print(Y_test.shape, '-----> Training Labels Shape')
# Out:
# (5634, 21) -----> Training Feature Shape
# (1409, 21) -----> Testing Feature Shape
# (5634,) -----> Training Labels Shape
# (1409,) -----> Training Labels Shape

# %%
from sklearn.linear_model import LogisticRegression

# %%
churn_log_model = LogisticRegression()

# %%
churn_log_model.fit(X_train, Y_train)
# Out:
# C:\Users\User\Desktop\Classification of Telco Customer\env\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
churn_predictions = churn_log_model.predict(X_test)

# %%
churn_predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(Y_test, churn_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87      1061
#            1       0.63      0.49      0.55       348
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.70      0.71      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
import sklearn.metrics as sm

# %%
accuracy_of_churn_model = sm.accuracy_score(Y_test, churn_predictions)

print('Accuracy Score ==', str(accuracy_of_churn_model))
# Out:
# Accuracy Score == 0.8041163946061036

# %%
from sklearn.metrics import confusion_matrix

# %%
import seaborn as sns; sns.set()

# %%
import matplotlib.pyplot as plt

# %%
get_ipython().run_line_magic('matplotlib', 'inline')

# %%
mat = confusion_matrix(Y_test, churn_predictions)

# %%
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False)
# Out:
# <Axes: >

# %%
churn_data_tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SeniorCitizen     7043 non-null   int64
#  1   Partner           7043 non-null   int64
#  2   Dependents        7043 non-null   int64
#  3   tenure            7043 non-null   int64
#  4   PhoneService      7043 non-null   int64
#  5   MultipleLines     7043 non-null   int64
#  6   InternetService   7043 non-null   int64
#  7   OnlineSecurity    7043 non-null   int64
#  8   OnlineBackup      7043 non-null   int64
#  9   DeviceProtection  7043 non-null   int64
#  10  TechSupport       7043 non-null   int64
#  11  StreamingTV       7043 non-null   int64
#  12  StreamingMovies   7043 non-null   int64
#  13  PaperlessBilling  7043 non-null   int64
#  14  MonthlyCharges    7043 non-null   int64
#  15  TotalCharges      7043 non-null   int32
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
import joblib

# %%
joblib.dump(churn_log_model, 'churn_model.pkl')
# Out:
# ['churn_model.pkl']

# %%
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
